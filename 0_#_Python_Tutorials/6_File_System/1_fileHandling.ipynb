# %%
import sys

# %%
f = open('test.txt', 'r')

# %%
print(f.read())
# Out:
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch

# %%
line = f.readlines()
print(line)
# Out:
# []

# %%
f.close()

# %%
with open('test.txt', 'r') as f:
    # print(f.read())
    # print(f.readline())
    # print(f.readlines())

    for line in f:
        print(line, end='')

    print(sys.getsizeof(f))
# Out:
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# 6 => Machine
# 7 => Learning
# 8 => Course
# 9 => from
# 10 => Scratch
# 1 => Hello
# 2 => This
# 3 => is
# 4 => a
# 5 => Complete
# ...
