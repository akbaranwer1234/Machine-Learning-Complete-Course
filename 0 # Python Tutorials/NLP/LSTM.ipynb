# %%
with open('LSTMtext.txt', 'r') as file:
    doc = file.read()

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# WARNING:tensorflow:From C:\Users\akber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([doc])
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'is': 3,
#  'cricket': 4,
#  'in': 5,
#  'what': 6,
#  'to': 7,
#  'of': 8,
#  'ball': 9,
#  'and': 10,
#  'by': 11,
#  'or': 12,
#  'batsman': 13,
#  'team': 14,
#  'with': 15,
#  'on': 16,
#  'an': 17,
#  'for': 18,
#  'leg': 19,
#  'shot': 20,
#  'batting': 21,
#  'bowler': 22,
#  'bat': 23,
#  'are': 24,
#  'runs': 25,
#  'delivery': 26,
#  'that': 27,
#  'match': 28,
#  'overs': 29,
#  'role': 30,
#  'bowled': 31,
#  'played': 32,
#  'test': 33,
#  'batsmen': 34,
#  'off': 35,
#  'side': 36,
#  'when': 37,
#  'between': 38,
#  'matches': 39,
#  'as': 40,
#  'run': 41,
#  'often': 42,
#  'field': 43,
#  'innings': 44,
#  'where': 45,
#  'century': 46,
#  'used': 47,
#  "batsman's": 48,
#  'fielding': 49,
#  'towards': 50,
#  'refers': 51,
#  'pitch': 52,
#  'over': 53,
#  'making': 54,
#  'stroke': 55,
#  'each': 56,
#  'international': 57,
#  'typically': 58,
#  'out': 59,
#  'from': 60,
#  'their': 61,
#  'limited': 62,
#  'body': 63,
#  'umpire': 64,
#  'spinner': 65,
#  'teams': 66,
#  'which': 67,
#  'such': 68,
#  'stumps': 69,
#  'more': 70,
#  'lbw': 71,
#  'first': 72,
#  'fast': 73,
#  'decisions': 74,
#  'responsible': 75,
#  'players': 76,
#  'how': 77,
#  'there': 78,
#  'one': 79,
#  'playing': 80,
#  'no': 81,
#  'score': 82,
#  'it': 83,
#  'bowling': 84,
#  'hat': 85,
#  'trick': 86,
#  'deliveries': 87,
#  'method': 88,
#  'before': 89,
#  'hit': 90,
#  'while': 91,
#  'occurs': 92,
#  'maiden': 93,
#  'scored': 94,
#  'wickets': 95,
#  'play': 96,
#  'umpires': 97,
#  'boundary': 98,
#  'spin': 99,
#  'sweep': 100,
#  'horizontal': 101,
#  'day': 102,
#  'odis': 103,
#  't20is': 104,
#  'single': 105,
#  'made': 106,
#  'wicket': 107,
#  'who': 108,
#  'but': 109,
#  'world': 110,
#  'difference': 111,
#  'yorker': 112,
#  'captain': 113,
#  'spins': 114,
#  'decision': 115,
#  'fielder': 116,
#  'opposition': 117,
#  'whether': 118,
#  'reverse': 119,
#  'two': 120,
#  'many': 121,
#  'main': 122,
#  'internationals': 123,
#  'twenty20': 124,
#  'up': 125,
#  'maximum': 126,
#  '20': 127,
#  'bowl': 128,
#  'all': 129,
#  'catch': 130,
#  'milestone': 131,
#  '100': 132,
#  'duckworth': 133,
#  'lewis': 134,
#  'stern': 135,
#  'dismissal': 136,
#  'if': 137,
#  'have': 138,
#  'due': 139,
#  "team's": 140,
#  'complete': 141,
#  'icc': 142,
#  'series': 143,
#  'championship': 144,
#  'tie': 145,
#  'at': 146,
#  'during': 147,
#  'attacking': 148,
#  'close': 149,
#  'googly': 150,
#  'toss': 151,
#  'line': 152,
#  'can': 153,
#  'cover': 154,
#  'appeal': 155,
#  'glance': 156,
#  'bye': 157,
#  'game': 158,
#  '22': 159,
#  'long': 160,
#  'period': 161,
#  '50': 162,
#  'gets': 163,
#  'area': 164,
#  'hitting': 165,
#  'make': 166,
#  'player': 167,
#  'both': 168,
#  'three': 169,
#  'consecutive': 170,
#  'same': 171,
#  'dls': 172,
#  'given': 173,
#  'would': 174,
#  'illegal': 175,
#  'crease': 176,
#  'league': 177,
#  'not': 178,
#  'within': 179,
#  'end': 180,
#  'after': 181,
#  'has': 182,
#  'determine': 183,
#  'around': 184,
#  'difficult': 185,
#  'without': 186,
#  'conditions': 187,
#  'tactical': 188,
#  'opposite': 189,
#  'direction': 190,
#  'deceive': 191,
#  'crusher': 192,
#  'injury': 193,
#  'based': 194,
#  'fair': 195,
#  'system': 196,
#  'any': 197,
#  'equipment': 198,
#  'partnership': 199,
#  'they': 200,
#  'grip': 201,
#  'duck': 202,
#  'attempt': 203,
#  'contact': 204,
#  'forward': 205,
#  'shots': 206,
#  'switch': 207,
#  'helicopter': 208,
#  'eleven': 209,
#  'rectangular': 210,
#  'consists': 211,
#  'formats': 212,
#  'format': 213,
#  'having': 214,
#  'yards': 215,
#  '12': 216,
#  'traditionally': 217,
#  'odi': 218,
#  't20i': 219,
#  'roles': 220,
#  'fielders': 221,
#  '15': 222,
#  'primary': 223,
#  'dismiss': 224,
#  'hits': 225,
#  'behind': 226,
#  'balls': 227,
#  'dismissals': 228,
#  'stumping': 229,
#  'outs': 230,
#  'rounder': 231,
#  'scores': 232,
#  'dismisses': 233,
#  'targets': 234,
#  'rain': 235,
#  'affected': 236,
#  'mode': 237,
#  'obstructed': 238,
#  'usually': 239,
#  'unfair': 240,
#  'wide': 241,
#  'council': 242,
#  'governing': 243,
#  'ashes': 244,
#  'cup': 245,
#  'premier': 246,
#  'ipl': 247,
#  'draw': 248,
#  'follow': 249,
#  'situation': 250,
#  'immediately': 251,
#  'taken': 252,
#  'powerplay': 253,
#  'allowing': 254,
#  'super': 255,
#  'pitches': 256,
#  'bouncer': 257,
#  'short': 258,
#  'pitched': 259,
#  'head': 260,
#  'tactic': 261,
#  'unsettle': 262,
#  'third': 263,
#  'catches': 264,
#  'other': 265,
#  'using': 266,
#  'perimeter': 267,
#  'beyond': 268,
#  'four': 269,
#  'six': 270,
#  'officials': 271,
#  'type': 272,
#  'conventional': 273,
#  'causing': 274,
#  'doosra': 275,
#  'designed': 276,
#  'nightwatchman': 277,
#  'sandshoe': 278,
#  'toes': 279,
#  'relies': 280,
#  'running': 281,
#  'law': 282,
#  'certain': 283,
#  'mcc': 284,
#  'club': 285,
#  'laws': 286,
#  'white': 287,
#  'red': 288,
#  'overthrow': 289,
#  'review': 290,
#  'technology': 291,
#  'referee': 292,
#  'ensure': 293,
#  'dead': 294,
#  'declaration': 295,
#  'set': 296,
#  'target': 297,
#  'opposing': 298,
#  'runner': 299,
#  'double': 300,
#  'achieved': 301,
#  'been': 302,
#  'higher': 303,
#  'fourth': 304,
#  'catching': 305,
#  'handed': 306,
#  'golden': 307,
#  'coach': 308,
#  'providing': 309,
#  'strategies': 310,
#  'performance': 311,
#  'chase': 312,
#  'report': 313,
#  'surface': 314,
#  'condition': 315,
#  'level': 316,
#  'groundsman': 317,
#  'resulting': 318,
#  'helmet': 319,
#  'risk': 320,
#  'tampering': 321,
#  'incident': 322,
#  'gain': 323,
#  'advantage': 324,
#  'analyst': 325,
#  'defensive': 326,
#  'straight': 327,
#  'against': 328,
#  'sledging': 329,
#  'achievement': 330,
#  'does': 331,
#  'celebrated': 332,
#  'significant': 333,
#  'debut': 334,
#  'domestic': 335,
#  'career': 336,
#  'dot': 337,
#  'considered': 338,
#  'delicate': 339,
#  'redirecting': 340,
#  'slight': 341,
#  'touch': 342,
#  'stump': 343,
#  'drive': 344,
#  'square': 345,
#  'cut': 346,
#  'point': 347,
#  'timing': 348,
#  'pull': 349,
#  'sweeping': 350,
#  '1': 351,
#  'circular': 352,
#  'yard': 353,
#  'center': 354,
#  '2': 355,
#  '3': 356,
#  '4': 357,
#  'longest': 358,
#  'five': 359,
#  'days': 360,
#  '5': 361,
#  'bats': 362,
#  'bowls': 363,
#  '6': 364,
#  'shortest': 365,
#  'restricted': 366,
#  '7': 367,
#  'structured': 368,
#  'chance': 369,
#  '8': 370,
#  'delivers': 371,
#  '9': 372,
#  'meters': 373,
#  '10': 374,
#  'leather': 375,
#  'cork': 376,
#  'core': 377,
#  'stitched': 378,
#  'tightly': 379,
#  '11': 380,
#  'limit': 381,
#  'number': 382,
#  '13': 383,
#  '14': 384,
#  'include': 385,
#  'bowlers': 386,
#  'rounders': 387,
#  'keepers': 388,
#  'delivered': 389,
#  '16': 390,
#  'delivering': 391,
#  'way': 392,
#  'induces': 393,
#  'mistake': 394,
#  '17': 395,
#  'keeper': 396,
#  "keeper's": 397,
#  'stand': 398,
#  'misses': 399,
#  'effect': 400,
#  '18': 401,
#  'excels': 402,
#  '19': 403,
#  '21': 404,
#  'mathematical': 405,
#  'formula': 406,
#  'adjust': 407,
#  'stands': 408,
#  'was': 409,
#  '23': 410,
#  'overstepping': 411,
#  'dangerous': 412,
#  '24': 413,
#  'so': 414,
#  'far': 415,
#  'deems': 416,
#  'unplayable': 417,
#  '25': 418,
#  'action': 419,
#  'attempting': 420,
#  '26': 421,
#  'global': 422,
#  '27': 423,
#  'england': 424,
#  'australia': 425,
#  '28': 426,
#  '29': 427,
#  'indian': 428,
#  'professional': 429,
#  'india': 430,
#  '30': 431,
#  'do': 432,
#  'allocated': 433,
#  'time': 434,
#  'whereas': 435,
#  'equal': 436,
#  '31': 437,
#  'second': 438,
#  'again': 439,
#  'substantial': 440,
#  'lead': 441,
#  '32': 442,
#  '33': 443,
#  'restrictions': 444,
#  'place': 445,
#  'freely': 446,
#  '34': 447,
#  'breaking': 448,
#  'particularly': 449,
#  'winner': 450,
#  'case': 451,
#  '35': 452,
#  'feet': 453,
#  '36': 454,
#  'rises': 455,
#  'sharply': 456,
#  'intimidate': 457,
#  '37': 458,
#  'official': 459,
#  'assists': 460,
#  'related': 461,
#  'stumpings': 462,
#  'calls': 463,
#  'television': 464,
#  'replays': 465,
#  '38': 466,
#  'outer': 467,
#  'this': 468,
#  'touching': 469,
#  'ground': 470,
#  'results': 471,
#  'scoring': 472,
#  '39': 473,
#  'competition': 474,
#  'organized': 475,
#  'best': 476,
#  '40': 477,
#  'calculate': 478,
#  'revised': 479,
#  'adverse': 480,
#  'weather': 481,
#  '41': 482,
#  'leader': 483,
#  'motivating': 484,
#  'representing': 485,
#  'interactions': 486,
#  '42': 487,
#  'confusion': 488,
#  '43': 489,
#  '44': 490,
#  'lower': 491,
#  'order': 492,
#  'sent': 493,
#  "day's": 494,
#  'protect': 495,
#  'accomplished': 496,
#  'facing': 497,
#  'new': 498,
#  'under': 499,
#  'fading': 500,
#  'light': 501,
#  '45': 502,
#  'also': 503,
#  'known': 504,
#  'toe': 505,
#  'discomfort': 506,
#  '46': 507,
#  'significance': 508,
#  'will': 509,
#  'winning': 510,
#  'option': 511,
#  'choose': 512,
#  '47': 513,
#  'primarily': 514,
#  'spinning': 515,
#  'pace': 516,
#  'bounce': 517,
#  '48': 518,
#  'marked': 519,
#  'indicate': 520,
#  'safe': 521,
#  'zone': 522,
#  'well': 523,
#  'must': 524,
#  'deliver': 525,
#  '49': 526,
#  'states': 527,
#  'be': 528,
#  'provided': 529,
#  'met': 530,
#  'â€ƒ': 531,
#  'marylebone': 532,
#  'london': 533,
#  'setting': 534,
#  'promoting': 535,
#  'spirit': 536,
#  'worldwide': 537,
#  '51': 538,
#  '52': 539,
#  '53': 540,
#  'enforcing': 541,
#  'ensuring': 542,
#  '54': 543,
#  'successfully': 544,
#  'cross': 545,
#  'fails': 546,
#  'prevent': 547,
#  'taking': 548,
#  'additional': 549,
#  'errant': 550,
#  'throw': 551,
#  '55': 552,
#  'drs': 553,
#  'assist': 554,
#  'correct': 555,
#  'challenge': 556,
#  'umpiring': 557,
#  '56': 558,
#  'appointed': 559,
#  'oversee': 560,
#  'conduct': 561,
#  'address': 562,
#  'disciplinary': 563,
#  'issues': 564,
#  'may': 565,
#  'arise': 566,
#  '57': 567,
#  'temporarily': 568,
#  'suspended': 569,
#  'becoming': 570,
#  'lodged': 571,
#  'serious': 572,
#  'intervention': 573,
#  'external': 574,
#  'factor': 575,
#  '58': 576,
#  'lost': 577,
#  'force': 578,
#  'result': 579,
#  '59': 580,
#  'substitute': 581,
#  'allowed': 582,
#  'behalf': 583,
#  'injured': 584,
#  'subject': 585,
#  'approval': 586,
#  '60': 587,
#  '61': 588,
#  'yields': 589,
#  '62': 590,
#  '200': 591,
#  '63': 592,
#  'including': 593,
#  'judging': 594,
#  'legally': 595,
#  '64': 596,
#  'trajectory': 597,
#  'predict': 598,
#  'flight': 599,
#  '65': 600,
#  'assisting': 601,
#  'administrative': 602,
#  'tasks': 603,
#  'arranging': 604,
#  'substitutions': 605,
#  'overseeing': 606,
#  'communicating': 607,
#  "teams'": 608,
#  'management': 609,
#  '66': 610,
#  'deceptive': 611,
#  'stock': 612,
#  'guard': 613,
#  '67': 614,
#  'right': 615,
#  'left': 616,
#  'mirror': 617,
#  'image': 618,
#  'swept': 619,
#  'handle': 620,
#  '68': 621,
#  'dismissed': 622,
#  'face': 623,
#  '69': 624,
#  'technical': 625,
#  'guidance': 626,
#  'developing': 627,
#  'skills': 628,
#  'formulating': 629,
#  'improve': 630,
#  '70': 631,
#  'required': 632,
#  'win': 633,
#  '71': 634,
#  'assessment': 635,
#  'prepared': 636,
#  'experts': 637,
#  'information': 638,
#  'factors': 639,
#  'grass': 640,
#  'moisture': 641,
#  'influence': 642,
#  'gameplay': 643,
#  '72': 644,
#  'preparing': 645,
#  'maintaining': 646,
#  'outfield': 647,
#  '73': 648,
#  'some': 649,
#  'part': 650,
#  'being': 651,
#  'clean': 652,
#  '74': 653,
#  'protective': 654,
#  'headgear': 655,
#  'worn': 656,
#  'reduce': 657,
#  'moving': 658,
#  '75': 659,
#  'alteration': 660,
#  "ball's": 661,
#  'roughing': 662,
#  'applying': 663,
#  'foreign': 664,
#  'substances': 665,
#  'swing': 666,
#  'seam': 667,
#  'movement': 668,
#  '76': 669,
#  'uses': 670,
#  'statistical': 671,
#  'analysis': 672,
#  'video': 673,
#  'provide': 674,
#  'insights': 675,
#  'into': 676,
#  "players'": 677,
#  'helping': 678,
#  'informed': 679,
#  '77': 680,
#  'shifting': 681,
#  'weight': 682,
#  'presenting': 683,
#  'defend': 684,
#  '78': 685,
#  'sequence': 686,
#  'defined': 687,
#  'trophy': 688,
#  'stake': 689,
#  '79': 690,
#  'positioned': 691,
#  'near': 692,
#  'create': 693,
#  'pressure': 694,
#  '80': 695,
#  'formal': 696,
#  'request': 697,
#  'asking': 698,
#  'appears': 699,
#  'warrant': 700,
#  '81': 701,
#  'practice': 702,
#  'verbally': 703,
#  'taunting': 704,
#  'distracting': 705,
#  'concentration': 706,
#  'psychological': 707,
#  '82': 708,
#  'rare': 709,
#  'notable': 710,
#  'sport': 711,
#  '83': 712,
#  'concede': 713,
#  'feat': 714,
#  'its': 715,
#  'tight': 716,
#  'economical': 717,
#  '84': 718,
#  'regarded': 719,
#  'mark': 720,
#  'excellence': 721,
#  '85': 722,
#  "player's": 723,
#  'appearance': 724,
#  'respective': 725,
#  'memorable': 726,
#  'moment': 727,
#  'marking': 728,
#  'beginning': 729,
#  'highest': 730,
#  '86': 731,
#  'believes': 732,
#  'prompting': 733,
#  'gone': 734,
#  '87': 735,
#  'ever': 736,
#  'major': 737,
#  '88': 738,
#  'success': 739,
#  'preventing': 740,
#  'accumulating': 741,
#  '89': 742,
#  '90': 743,
#  '91': 744,
#  'elegant': 745,
#  'driving': 746,
#  'region': 747,
#  'most': 748,
#  'aesthetically': 749,
#  'pleasing': 750,
#  '92': 751,
#  'cutting': 752,
#  'backward': 753,
#  'positions': 754,
#  'executed': 755,
#  'precision': 756,
#  'placement': 757,
#  '93': 758,
#  'aggressive': 759,
#  'pulling': 760,
#  'aimed': 761,
#  '94': 762,
#  'risky': 763,
#  'counter': 764,
#  'requiring': 765,
#  'skill': 766,
#  'execute': 767,
#  'effectively': 768,
#  '95': 769,
#  'unconventional': 770,
#  'reversing': 771,
#  'surprising': 772,
#  'carrying': 773,
#  '96': 774,
#  'audacious': 775,
#  'changing': 776,
#  'stance': 777,
#  'mid': 778,
#  'popularized': 779,
#  'modern': 780,
#  'outfox': 781,
#  '97': 782,
#  'unorthodox': 783,
#  'flicking': 784,
#  'following': 785,
#  'through': 786,
#  'full': 787,
#  'rotation': 788,
#  'resembling': 789,
#  'blade': 790,
#  'famously': 791,
#  'associated': 792,
#  'former': 793,
#  'cricketer': 794,
#  'ms': 795,
#  'dhoni': 796,
#  '98': 797,
#  'deflects': 798,
#  'pads': 799,
#  'retrieve': 800,
#  '99': 801,
#  'passes': 802,
#  "wicketkeeper's": 803,
#  'missed': 804,
#  "fielder's": 805,
#  'failure': 806,
#  'stop': 807,
#  'return': 808,
#  'wicketkeeper': 809}

# %%
# sentences = doc.split('\n')
Uni_Gram = []
Bi_Gram = []
Tri_Gram = []
Quad_Gram = []
Penta_Gram = []
Hexa_Gram = []

for sentence in doc.split('\n'):
    tokenized_sentences = tokenizer.texts_to_sequences([sentence])[0]
    
    for i in range(1, len(tokenized_sentences)):
        Uni_Gram.append(tokenized_sentences[:i])
        Bi_Gram.append(tokenized_sentences[:i+1])
        Tri_Gram.append(tokenized_sentences[:i+2])
        Quad_Gram.append(tokenized_sentences[:i+3])
        Penta_Gram.append(tokenized_sentences[:i+4])
        Hexa_Gram.append(tokenized_sentences[:i+5])

# %%
maxLen = max([len(x) for x in Bi_Gram])
maxLen
# Out:
# 58

# %%
from keras.preprocessing.sequence import pad_sequences
padded_uni_gram_sequences = pad_sequences(Uni_Gram, maxlen=maxLen, padding='pre')
padded_bi_gram_sequences = pad_sequences(Bi_Gram, maxlen=maxLen, padding='pre')
padded_tri_gram_sequences = pad_sequences(Tri_Gram, maxlen=maxLen, padding='pre')
padded_quad_gram_sequences = pad_sequences(Quad_Gram, maxlen=maxLen, padding='pre')
padded_penta_gram_sequences = pad_sequences(Penta_Gram, maxlen=maxLen, padding='pre')
padded_hexa_gram_sequences = pad_sequences(Hexa_Gram, maxlen=maxLen, padding='pre')

# %%
# print(padded_uni_gram_sequences)
# print(padded_uni_gram_sequences[:,:-1][1])
X_uni_gram = padded_uni_gram_sequences[:,:-1]
X_bi_gram = padded_bi_gram_sequences[:,:-1]
X_tri_gram = padded_tri_gram_sequences[:,:-1]
X_quad_gram = padded_quad_gram_sequences[:,:-1]
X_penta_gram = padded_penta_gram_sequences[:,:-1]
X_hexa_gram = padded_hexa_gram_sequences[:,:-1]

y_uni_gram = padded_uni_gram_sequences[:,-1]
y_bi_gram = padded_bi_gram_sequences[:,-1]
y_tri_gram = padded_tri_gram_sequences[:,-1]
y_quad_gram = padded_quad_gram_sequences[:,-1]
y_penta_gram = padded_penta_gram_sequences[:,-1]
y_hexa_gram = padded_hexa_gram_sequences[:,-1]

print(X_uni_gram.shape, X_bi_gram.shape, X_tri_gram.shape, X_quad_gram.shape, X_penta_gram.shape, X_hexa_gram.shape)
print(y_uni_gram.shape, y_bi_gram.shape, y_tri_gram.shape, y_quad_gram.shape, y_penta_gram.shape, y_hexa_gram.shape)
# Out:
# (3421, 57) (3421, 57) (3421, 57) (3421, 57) (3421, 57) (3421, 57)
# (3421,) (3421,) (3421,) (3421,) (3421,) (3421,)

# %%
from keras.utils import to_categorical

# %%
y_uni_gram = to_categorical(y_uni_gram, num_classes=len(tokenizer.word_index)+1)

# %%
y_bi_gram = to_categorical(y_bi_gram, num_classes=len(tokenizer.word_index)+1)

# %%
y_tri_gram = to_categorical(y_tri_gram, num_classes=len(tokenizer.word_index)+1)

# %%
y_quad_gram = to_categorical(y_quad_gram, num_classes=len(tokenizer.word_index)+1)

# %%
y_penta_gram = to_categorical(y_penta_gram, num_classes=len(tokenizer.word_index)+1)

# %%
y_hexa_gram = to_categorical(y_hexa_gram, num_classes=len(tokenizer.word_index)+1)

# %%
print(y_uni_gram.shape, y_bi_gram.shape, y_tri_gram.shape, y_quad_gram.shape, y_penta_gram.shape, y_hexa_gram.shape)
# Out:
# (3421, 810) (3421, 810) (3421, 810) (3421, 810) (3421, 810) (3421, 810)

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, GRU

# %%
vocab_size = len(tokenizer.word_index)
padded_sequence_Length = len(padded_bi_gram_sequences[0])
print(vocab_size, padded_sequence_Length)
# Out:
# 809 58

# %%
# model = Sequential()
# model.add(Embedding(input_dim=vocab_size+1, output_dim=100, input_length=padded_sequence_Length-1))
# model.add(LSTM(units=150))
# model.add(Dense(units=vocab_size+1, activation='softmax'))
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.summary()

model = Sequential()
model.add(Embedding(input_dim=vocab_size+1, output_dim=100, input_length=padded_sequence_Length-1))
model.add(GRU(units=150))
model.add(Dense(units=vocab_size+1, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\akber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\akber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 57, 100)           81000
#
#  gru (GRU)                   (None, 150)               113400
#
#  dense (Dense)               (None, 810)               122310
#
# =================================================================
# Total params: 316710 (1.21 MB)
# Trainable params: 316710 (1.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_bi_gram, y_bi_gram, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\akber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\akber\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
# 107/107 [==============================] - 28s 259ms/step - loss: 0.1385 - accuracy: 0.9602
# Epoch 91/100
# 107/107 [==============================] - 28s 259ms/step - loss: 0.1366 - accuracy: 0.9617
# Epoch 92/100
# 107/107 [==============================] - 26s 247ms/step - loss: 0.1359 - accuracy: 0.9620
# Epoch 93/100
# 107/107 [==============================] - 12s 108ms/step - loss: 0.1401 - accuracy: 0.9608
# Epoch 94/100
# 107/107 [==============================] - 5s 51ms/step - loss: 0.1356 - accuracy: 0.9623
# Epoch 95/100
# 107/107 [==============================] - 5s 49ms/step - loss: 0.1354 - accuracy: 0.9614
# Epoch 96/100
# 107/107 [==============================] - 5s 48ms/step - loss: 0.1316 - accuracy: 0.9640
# Epoch 97/100
# 107/107 [==============================] - 6s 57ms/step - loss: 0.1352 - accuracy: 0.9620
# Epoch 98/100
# 107/107 [==============================] - 6s 57ms/step - loss: 0.1339 - accuracy: 0.9638
# Epoch 99/100
# 107/107 [==============================] - 4s 42ms/step - loss: 0.1326 - accuracy: 0.9638
# Epoch 100/100
# 107/107 [==============================] - 4s 37ms/step - loss: 0.1320 - accuracy: 0.9643

# %%
import numpy as np

# %%
import time
text = "The wicket-keeper's role is to"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=padded_sequence_Length-1, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 [==============================] - 1s 614ms/step
# The wicket-keeper's role is to stand
# 1/1 [==============================] - 0s 24ms/step
# The wicket-keeper's role is to stand behind
# 1/1 [==============================] - 0s 25ms/step
# The wicket-keeper's role is to stand behind the
# 1/1 [==============================] - 0s 26ms/step
# The wicket-keeper's role is to stand behind the stumps
# 1/1 [==============================] - 0s 21ms/step
# The wicket-keeper's role is to stand behind the stumps to
# 1/1 [==============================] - 0s 24ms/step
# The wicket-keeper's role is to stand behind the stumps to catch
# 1/1 [==============================] - 0s 23ms/step
# The wicket-keeper's role is to stand behind the stumps to catch balls
# 1/1 [==============================] - 0s 25ms/step
# The wicket-keeper's role is to stand behind the stumps to catch balls that
# 1/1 [==============================] - 0s 27ms/step
# The wicket-keeper's role is to stand behind the stumps to catch balls that the
# 1/1 [==============================] - 0s 29ms/step
# The wicket-keeper's role is to stand behind the stumps to catch balls that the batsman

# %%
model.loss
# Out:
# 'categorical_crossentropy'

# %%
# Uni_Gram = []
# Bi_Gram = []
# Tri_Gram = []
# Quad_Gram = []
# Penta_Gram = []
# Hexa_Gram = []

# tokenized_sentences = tokenizer.texts_to_sequences(sentences)[0]
# tokenized_sentences

# # for i in tokenized_sentences:
# #     for i in range(1,len(tokenized_sentences)):
# #         Uni_Gram.append(tokenized_sentences[:i])
# #         Bi_Gram.append(tokenized_sentences[:i+1])
        
# # Bi_Gram
# Out:
# [351, 6, 3, 4]
