# %%
import numpy as np
import random

# %%
X_train = np.random.randint(0, 21, 40).reshape(20, 2)
y_train = np.random.randint(0, 2, 20).reshape(20, 1)

# %%
X_train[:2]
# Out:
# array([[ 7, 10],
#        [ 3,  2]])

# %%
y_train[:5]
# Out:
# array([[0],
#        [1],
#        [1],
#        [0],
#        [1]])

# %%
X_test = np.random.randint(0, 21, 20).reshape(10, 2)

# %%
y_test = np.random.randint(0, 2, 10).reshape(10, 1)

# %%
X_test[:5]
# Out:
# array([[13, 10],
#        [ 8,  3],
#        [ 1,  2],
#        [ 8,  3],
#        [20,  3]])

# %%
y_test[:5]
# Out:
# array([[0],
#        [1],
#        [0],
#        [1],
#        [1]])

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 1, 1, 1, 0, 1, 0, 0, 1])

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# %%
tree.plot_tree(clf, filled=True)
plt.show()

# %%
X_train = np.random.randint(0, 21, 40).reshape(20, 2)
y_train = np.random.randint(0, 5, 20).reshape(20, 1)

# %%
X_test = np.random.randint(0, 21, 20).reshape(10, 2)
y_test = np.random.randint(0, 5, 10).reshape(10, 1)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
tree.plot_tree(clf, filled=True)
plt.show()

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# iris.target
# iris.data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.5, random_state=42)

# %%
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
y_pred = clf.predict(X_test)

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
tree.plot_tree(clf, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
# plt.figure(figsize=(6,6))
plt.show()
