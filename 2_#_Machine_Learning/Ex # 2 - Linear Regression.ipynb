# %% [markdown]
# ## Linear Regression
#
# Tour task is to predict Median House Values in Californian Districts dataset (https://www.kaggle.com/datasets/camnugent/california-housing-prices), given a number of features from these districts.

# %%
# Necessary imports

import sklearn
import numpy as np
import os
import pandas as pd

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# #### Fetching the Dataset

# %%
import os
import tarfile
import urllib.request

# %%
# download and extract a housing dataset from the dataset URL

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

# %%
def fetch_housing_data(housing_url = HOUSING_URL, housing_path = HOUSING_PATH):
    if not os.path.isdir(housing_path):
        os.makedirs(housing_path)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path = housing_path)
    housing_tgz.close()

# %%
fetch_housing_data()

# %%
# load the dataset 

def load_housing_data(housing_path = HOUSING_PATH):
    csv_path = os.path.join(housing_path, "housing.csv")
    return pd.read_csv(csv_path)

# %%
housing = load_housing_data()
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# get dataframe information

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
# only this column is categorical 

housing["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
# housing.hist() generates histograms for all the numerical columns 

housing.hist(bins = 50, figsize = (20, 15))
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size = 0.2, random_state = 42)

# %%
test_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             NaN
# 3024     -119.46     35.14                30.0       2943.0             NaN
# 15663    -122.44     37.80                52.0       3830.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
# 9814     -121.93     36.62                34.0       2351.0             NaN
#
#        population  households  median_income  median_house_value  \
# 20046      1392.0       359.0         1.6812             47700.0
# 3024       1565.0       584.0         2.5313             45800.0
# 15663      1310.0       963.0         3.4801            500001.0
# 20484      1705.0       495.0         5.7376            218600.0
# 9814       1063.0       428.0         3.7250            278000.0
#
#       ocean_proximity
# 20046          INLAND
# 3024           INLAND
# 15663        NEAR BAY
# 20484       <1H OCEAN
# 9814       NEAR OCEAN

# %%
housing["median_income"].hist()
# Out:
# <Axes: >

# %%
housing["income_cat"] = pd.cut(housing["median_income"],
                               bins = [0., 1.5, 3.0, 4.5, 6., np.inf],
                               labels = [1, 2, 3, 4, 5])

# %%
housing["income_cat"].value_counts()
# Out:
# income_cat
# 3    7236
# 2    6581
# 4    3639
# 5    2362
# 1     822
# Name: count, dtype: int64

# %%
housing["income_cat"].hist()
# Out:
# <Axes: >

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)

for train_index, test_index in split.split(housing, housing["income_cat"]):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12655    -121.46     38.52                29.0       3873.0           797.0
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value  \
# 12655      2237.0       706.0         2.1736             72100.0
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5
# 2908           INLAND          2
# 14053      NEAR OCEAN          2
# 20496       <1H OCEAN          3
# ...               ...        ...
# 15174       <1H OCEAN          4
# 12661          INLAND          2
# 19263       <1H OCEAN          3
# 19140       <1H OCEAN          3
# 19773          INLAND          3
#
# [16512 rows x 11 columns]

# %%
strat_test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5241     -118.39     34.12                29.0       6447.0          1012.0
# 17352    -120.42     34.89                24.0       2020.0           307.0
# 3505     -118.45     34.25                36.0       1453.0           270.0
# 7777     -118.10     33.91                35.0       1653.0           325.0
# 14155    -117.07     32.77                38.0       3779.0           614.0
# ...          ...       ...                 ...          ...             ...
# 12182    -117.29     33.72                19.0       2248.0           427.0
# 7275     -118.24     33.99                33.0        885.0           294.0
# 17223    -119.72     34.44                43.0       1781.0           342.0
# 10786    -117.91     33.63                30.0       2071.0           412.0
# 3965     -118.56     34.19                36.0       2600.0           441.0
#
#        population  households  median_income  median_house_value  \
# 5241       2184.0       960.0         8.2816            500001.0
# 17352       855.0       283.0         5.0099            162500.0
# 3505        808.0       275.0         4.3839            204600.0
# 7777       1072.0       301.0         3.2708            159700.0
# 14155      1495.0       614.0         4.3529            184000.0
# ...           ...         ...            ...                 ...
# 12182      1207.0       368.0         2.8170            110000.0
# 7275       1270.0       282.0         2.1615            118800.0
# 17223       663.0       358.0         4.7000            293800.0
# 10786      1081.0       412.0         4.9125            335700.0
# 3965       1246.0       426.0         4.1111            215600.0
#
#       ocean_proximity income_cat
# 5241        <1H OCEAN          5
# 17352       <1H OCEAN          4
# 3505        <1H OCEAN          3
# 7777        <1H OCEAN          3
# 14155      NEAR OCEAN          3
# ...               ...        ...
# 12182       <1H OCEAN          2
# 7275        <1H OCEAN          2
# 17223       <1H OCEAN          4
# 10786       <1H OCEAN          4
# 3965        <1H OCEAN          3
#
# [4128 rows x 11 columns]

# %%
strat_test_set["income_cat"].value_counts() / len(strat_test_set)
# Out:
# income_cat
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
housing["income_cat"].value_counts() / len(housing)
# Out:
# income_cat
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: count, dtype: float64

# %% [markdown]
# #### Discover and Viualize the Data to Gain Insights

# %%
housing = strat_train_set.copy()

# %%
housing.plot(kind = "scatter", x = "longitude", y = "latitude")
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
housing.plot(kind = "scatter", x = "longitude", y = "latitude", alpha = 0.4,
             s = housing["population"]/100, label = "population", figsize = (14, 8),
             c = "median_house_value", cmap = plt.get_cmap("jet"), colorbar = True, sharex = False)
plt.legend()

# c: Sets the color of the data points based on the "median_house_value" column
# cmap: Sets the colormap to be used for coloring the points

# %%
# Getting the correlation to measure the statistical relationship between the variables

corr_matrix = housing.corr()

# %%
corr_matrix["median_house_value"].sort_values(ascending = False)

# %% [markdown]
# #### Prepare the data for training

# %%
housing = strat_train_set.drop("median_house_value", axis = 1) # drop target/labels for training set

# %%
housing_labels = strat_train_set["median_house_value"].copy()

# %%
# Handling missing values 

sample_incomplete_rows = housing[housing.isnull().any(axis = 1)].head()
sample_incomplete_rows
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1606     -122.08     37.88                26.0       2947.0             NaN
# 10915    -117.87     33.73                45.0       2264.0             NaN
# 19150    -122.70     38.35                14.0       2313.0             NaN
# 4186     -118.23     34.13                48.0       1308.0             NaN
# 16885    -122.40     37.58                26.0       3281.0             NaN
#
#        population  households  median_income ocean_proximity income_cat
# 1606        825.0       626.0         2.9330        NEAR BAY          2
# 10915      1970.0       499.0         3.4193       <1H OCEAN          3
# 19150       954.0       397.0         3.7813       <1H OCEAN          3
# 4186        835.0       294.0         4.2891       <1H OCEAN          3
# 16885      1145.0       480.0         6.3580      NEAR OCEAN          5

# %%
median = housing["total_bedrooms"].median()
sample_incomplete_rows["total_bedrooms"].fillna(median, inplace = True)

# %%
sample_incomplete_rows
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1606     -122.08     37.88                26.0       2947.0           433.0
# 10915    -117.87     33.73                45.0       2264.0           433.0
# 19150    -122.70     38.35                14.0       2313.0           433.0
# 4186     -118.23     34.13                48.0       1308.0           433.0
# 16885    -122.40     37.58                26.0       3281.0           433.0
#
#        population  households  median_income ocean_proximity income_cat
# 1606        825.0       626.0         2.9330        NEAR BAY          2
# 10915      1970.0       499.0         3.4193       <1H OCEAN          3
# 19150       954.0       397.0         3.7813       <1H OCEAN          3
# 4186        835.0       294.0         4.2891       <1H OCEAN          3
# 16885      1145.0       480.0         6.3580      NEAR OCEAN          5

# %% [markdown]
# #### Let's build a pipeline for preprocessing the numerical attributes

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
imputer = SimpleImputer(strategy = "median")

# %%
# Remove the text attribute because median can only be calculated on numerical attributes

housing_num = housing.drop("ocean_proximity", axis = 1)

# %%
num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy = "median")),
        ('std_scaler', StandardScaler()),])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
housing_num_tr[0]
# Out:
# array([-0.94135046,  1.34743822,  0.02756357,  0.58477745,  0.64037127,
#         0.73260236,  0.55628602, -0.8936472 , -0.95468705])

# %% [markdown]
# #### Complete Pipeline: Handle Missing Values and Convert Categorial Data to One-Hot Encoding

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
num_attribs = list(housing_num)
cat_attribs = ["ocean_proximity"]

# %%
full_pipeline = ColumnTransformer([
        ("num", num_pipeline, num_attribs),
        ("cat", OneHotEncoder(), cat_attribs),])

# %%
housing_prepared = full_pipeline.fit_transform(housing)

# %%
housing_prepared[0]
# Out:
# array([-0.94135046,  1.34743822,  0.02756357,  0.58477745,  0.64037127,
#         0.73260236,  0.55628602, -0.8936472 , -0.95468705,  0.        ,
#         1.        ,  0.        ,  0.        ,  0.        ])

# %%
housing_prepared.shape
# Out:
# (16512, 14)

# %% [markdown]
# ##### Also apply same transformations to test set

# %%
housing_test = strat_test_set.drop("median_house_value", axis = 1) # drop labels for test set
housing_test = full_pipeline.transform(housing_test)

# %%
housing_test_labels = strat_test_set["median_house_value"].copy()
housing_test_labels
# Out:
# 5241     500001.0
# 17352    162500.0
# 3505     204600.0
# 7777     159700.0
# 14155    184000.0
#            ...
# 12182    110000.0
# 7275     118800.0
# 17223    293800.0
# 10786    335700.0
# 3965     215600.0
# Name: median_house_value, Length: 4128, dtype: float64

# %% [markdown]
# ### Training the Model

# %% [markdown]
# ##### Linear Regression: SKlearn Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
clf = LinearRegression()
clf.fit(housing_prepared, housing_labels)
# Out:
# LinearRegression()

# %%
predictions = clf.predict(housing_test)
predictions
# Out:
# array([416444.55142975, 294941.34070285, 242588.43973461, ...,
#        316384.15327688, 273441.01552856, 238774.02107991])

# %% [markdown]
# ##### Linear Regression Using one Dense Layer

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    layers.Dense(1)])

# %%
model.compile(optimizer = "sgd", loss = 'mean_absolute_error')

# %%
model.fit(housing_prepared, housing_labels, epochs = 20, validation_split = 0.2, batch_size = 32)
# Out:
# Epoch 1/20
# 413/413 [==============================] - 2s 3ms/step - loss: 206851.5781 - val_loss: 207602.2031
# Epoch 2/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206846.2969 - val_loss: 207596.8125
# Epoch 3/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206840.8125 - val_loss: 207591.2344
# Epoch 4/20
# 413/413 [==============================] - 1s 2ms/step - loss: 206835.1719 - val_loss: 207585.8906
# Epoch 5/20
# 413/413 [==============================] - 1s 2ms/step - loss: 206829.8281 - val_loss: 207580.3906
# Epoch 6/20
# 413/413 [==============================] - 1s 2ms/step - loss: 206824.1562 - val_loss: 207574.9688
# Epoch 7/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206818.7031 - val_loss: 207569.5156
# Epoch 8/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206813.1562 - val_loss: 207564.0000
# Epoch 9/20
# 413/413 [==============================] - 1s 2ms/step - loss: 206807.8281 - val_loss: 207558.5938
# Epoch 10/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206802.3594 - val_loss: 207553.1094
# Epoch 11/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206796.9688 - val_loss: 207547.6094
# Epoch 12/20
# 413/413 [==============================] - 1s 2ms/step - loss: 206791.3438 - val_loss: 207542.2500
# Epoch 13/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206785.7812 - val_loss: 207536.7500
# Epoch 14/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206780.3750 - val_loss: 207531.2344
# Epoch 15/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206774.8125 - val_loss: 207525.8438
# Epoch 16/20
# 413/413 [==============================] - 2s 4ms/step - loss: 206769.4688 - val_loss: 207520.3438
# Epoch 17/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206763.9062 - val_loss: 207514.8750
# Epoch 18/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206758.5625 - val_loss: 207509.5000
# Epoch 19/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206752.9688 - val_loss: 207503.9531
# Epoch 20/20
# 413/413 [==============================] - 1s 3ms/step - loss: 206747.5625 - val_loss: 207498.5156

# %%
model.evaluate(housing_test, housing_test_labels)
# Out:
# 129/129 [==============================] - 0s 2ms/step - loss: 206147.9844
# 206147.984375

# %%
some_data = housing.iloc[:5]
some_labels = housing_labels.iloc[:5]

# %%
some_data_prepared = full_pipeline.transform(some_data)

# %%
print("Predictions:", model.predict(some_data_prepared))
# Out:
# 1/1 [==============================] - 0s 191ms/step
# Predictions: [[111.49852 ]
#  [ 89.39548 ]
#  [110.376656]
#  [ 92.08234 ]
#  [118.01836 ]]

# %%
print("Labels:", list(some_labels))
# Out:
# Labels: [72100.0, 279600.0, 82700.0, 112500.0, 238300.0]

# %% [markdown]
# Terrible results with simple model? Let us try something else.

# %% [markdown]
# ##### Multi Layer Perceptron

# %%
model = keras.Sequential([
    layers.Dense(30, activation = "relu"),
    layers.Dense(1)])

# %%
model.compile(optimizer = "sgd", loss = 'mean_absolute_error')

# %%
model.fit(housing_prepared, housing_labels, epochs = 20, validation_split = 0.2, batch_size = 32)
# Out:
# Epoch 1/20
# 413/413 [==============================] - 3s 5ms/step - loss: 206473.0000 - val_loss: 204028.7188
# Epoch 2/20
# 413/413 [==============================] - 1s 3ms/step - loss: 103579.9453 - val_loss: 50884.7539
# Epoch 3/20
# 413/413 [==============================] - 1s 3ms/step - loss: 49423.1992 - val_loss: 48391.7227
# Epoch 4/20
# 413/413 [==============================] - 1s 3ms/step - loss: 48020.3945 - val_loss: 47536.1953
# Epoch 5/20
# 413/413 [==============================] - 1s 3ms/step - loss: 47355.7070 - val_loss: 47079.3633
# Epoch 6/20
# 413/413 [==============================] - 1s 3ms/step - loss: 46814.5117 - val_loss: 46591.4375
# Epoch 7/20
# 413/413 [==============================] - 2s 4ms/step - loss: 46423.1328 - val_loss: 46238.8164
# Epoch 8/20
# 413/413 [==============================] - 1s 3ms/step - loss: 46070.7539 - val_loss: 46033.4805
# Epoch 9/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45829.2656 - val_loss: 46062.9375
# Epoch 10/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45598.7617 - val_loss: 45888.8750
# Epoch 11/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45442.6133 - val_loss: 45430.8828
# Epoch 12/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45255.0391 - val_loss: 45294.9570
# Epoch 13/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45105.5312 - val_loss: 45147.1133
# Epoch 14/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44941.6406 - val_loss: 45114.6484
# Epoch 15/20
# 413/413 [==============================] - 1s 4ms/step - loss: 44769.9844 - val_loss: 45107.0430
# Epoch 16/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44614.0312 - val_loss: 44646.6797
# Epoch 17/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44498.3242 - val_loss: 44508.2930
# Epoch 18/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44329.1250 - val_loss: 44269.8672
# Epoch 19/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44135.5352 - val_loss: 44447.5742
# Epoch 20/20
# 413/413 [==============================] - 1s 3ms/step - loss: 44048.8789 - val_loss: 43917.3438

# %%
model.evaluate(housing_test, housing_test_labels)
# Out:
# 129/129 [==============================] - 0s 3ms/step - loss: 44007.8945
# 44007.89453125

# %%
print("Predictions:", model.predict(some_data_prepared))
# Out:
# 1/1 [==============================] - 0s 98ms/step
# Predictions: [[ 75654.94]
#  [304305.84]
#  [113607.84]
#  [156152.52]
#  [204590.4 ]]

# %%
print("Labels:", list(some_labels))
# Out:
# Labels: [72100.0, 279600.0, 82700.0, 112500.0, 238300.0]

# %% [markdown]
# Self Assessment Tasks

# %%
model = keras.Sequential([
    layers.Dense(10, activation = 'relu'),
    # layers.Dense(10, activation = "relu"),
    layers.Dense(1)])



optimizer = keras.optimizers.SGD(lr=0.01)

model.compile(optimizer = optimizer, loss = 'mean_absolute_error')

model.fit(housing_prepared, housing_labels, epochs = 20, validation_split = 0.2, batch_size = 32)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/20
# 413/413 [==============================] - 4s 7ms/step - loss: 206179.4062 - val_loss: 201242.6562
# Epoch 2/20
# 413/413 [==============================] - 2s 4ms/step - loss: 93995.0625 - val_loss: 51067.5430
# Epoch 3/20
# 413/413 [==============================] - 2s 4ms/step - loss: 49325.6797 - val_loss: 48272.7188
# Epoch 4/20
# 413/413 [==============================] - 2s 4ms/step - loss: 48054.6016 - val_loss: 47543.2109
# Epoch 5/20
# 413/413 [==============================] - 2s 5ms/step - loss: 47422.1406 - val_loss: 47426.8516
# Epoch 6/20
# 413/413 [==============================] - 1s 3ms/step - loss: 46984.4180 - val_loss: 46819.2852
# Epoch 7/20
# 413/413 [==============================] - 2s 4ms/step - loss: 46622.1562 - val_loss: 46562.1016
# Epoch 8/20
# 413/413 [==============================] - 2s 4ms/step - loss: 46284.7070 - val_loss: 46343.6797
# Epoch 9/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45959.0508 - val_loss: 46225.2773
# Epoch 10/20
# 413/413 [==============================] - 2s 4ms/step - loss: 45747.6484 - val_loss: 45610.1641
# Epoch 11/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45553.1289 - val_loss: 45777.5000
# Epoch 12/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45323.7266 - val_loss: 45700.5664
# Epoch 13/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45198.4961 - val_loss: 45393.2070
# Epoch 14/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45099.6758 - val_loss: 45366.8047
# Epoch 15/20
# 413/413 [==============================] - 1s 3ms/step - loss: 45031.3828 - val_loss: 45323.6094
# Epoch 16/20
# 413/413 [==============================] - 2s 4ms/step - loss: 44896.8203 - val_loss: 45034.3125
# Epoch 17/20
# 413/413 [==============================] - 2s 4ms/step - loss: 44750.5273 - val_loss: 44927.8594
# Epoch 18/20
# 413/413 [==============================] - 2s 4ms/step - loss: 44614.2148 - val_loss: 44915.5117
# Epoch 19/20
# 413/413 [==============================] - 1s 4ms/step - loss: 44485.8125 - val_loss: 44936.6562
# Epoch 20/20
# 413/413 [==============================] - 1s 2ms/step - loss: 44314.6875 - val_loss: 44839.2852
